# %%
import random

put_question = input("문제를 입력하세요: ").split('.')

random.shuffle(put_question)

for index in range(len(put_question)):
    indexed_question = str(index + 1) + '.' + put_question[index]
    print(indexed_question + '\n')
# Out:
# 문제를 입력하세요:  인공지능의 역사는 그리 오래되지 않았으나, 약 150년 정도의 전통을 가지고 있다 (O/X). 4차 산업혁명은 인공지능 기술과 매우 관련이 깊다 (O/X). 연결주의 인공지능 계열에 속하는 것은 규칙기반 인공지능이다 (O/X). 민스키는 비교적 초기 인공지능 연구자에 속하는 인물로서 인공지능 연구에 큰 공헌을 하였다 (O/X). 인공지능 바둑 프로그램인 알파고는 인공지능의 초창기인 1970년대에 개발되었다 (O/X). 인공지능이 만드는 문장에서 가장 핵심적인 사항은 구문도 맞고, 의미가 통해야 한다 (O/X). 인공지능 소프트웨어 기자인 기자 로봇은 현재 미국에서 주식 시황이나 스포츠 기사를 실제로 작성하며 활동하고 있다 (O/X). 자율주행 자동차는 현재 상업용으로 활발하게 이용되고 있다 (O/X). 고등학생 수준의 인공지능 글쓰기는 미국에서는 이미 가능하다 (O/X). 인공지능이 그린 미술 작품 중 실제 5억 원이란 거금으로 경매로 거래되는 것도 있으며, 서명 대신에 생성 알고리즘이 적혀 있다 (O/X). 그래픽카드의 핵심 칩으로 인공지능 프로그램에서 그래픽 정보 등을 빠르게 처리하는 것은?. 1957년 로젠블럿이 개발하여 A, B, C 등 문자를 인식할 수 있었던 시스템은?. 생각하는 기계에 대한 논리를 구상하고 튜링 테스트를 처음으로 제안한 사람은?. 1957년 다트머스 대학에서의 워크샵에서 인공지능이란 용어를 처음으로 제안한 사람은 ()이다. 2011년 미국의 유명한 퀴즈쇼에서 역대 인간 우승자들과의 대결에서 승리를 차지한 컴퓨터 시스템은 ()이다. 1997년에 IBM이 개발한 체스 전용 컴퓨터는 ()이다. 인공지능 기술의 발달로 ()가 머지않아 상용화되면 택시나 버스 운전사들의 일자리가 줄어들 수 있다. 인공지능 주제와 관련이 비교적 적은 것은? ① 인간의 지능을 모델링하는 기술 ② 인간 두뇌에 도전하는 기술 ③ 지능적인 원리를 컴퓨터에 적용하는 기술 ④ 현재 대부분의 문제 해결이 가능한 기술. 다음의 컴퓨터 장치 중 인간 
# ...
